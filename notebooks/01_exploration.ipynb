# %% [markdown]
# # 01 — Exploration des données ONISR
#
# Notebook d'exploration rapide après l'extraction.
# Pré-requis : `python -m src.extract.run_all` exécuté.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import duckdb
from src.utils.config import settings

con = duckdb.connect(str(settings.duckdb_path), read_only=True)
con.execute("SHOW TABLES").df()

# %%
# Aperçu fct_accidents
df = con.execute("SELECT * FROM marts.fct_accidents LIMIT 100").df()
df.head()

# %%
# Stats de qualité
from src.quality.expectations import run_suite_accidents
checks = run_suite_accidents(df)
for c in checks:
    print(c)
